# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/nizomidin/Study/citation-matcher/data/processed/ranking_dataset_with_features.csv")

# %%
df[
    [
        "title_similarity",
        "title_token_set_similarity"
    ]
].corr()
# Out:
#                             title_similarity  title_token_set_similarity
# title_similarity                    1.000000                    0.944105
# title_token_set_similarity          0.944105                    1.000000
